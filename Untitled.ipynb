# %%
import tweepy
from textblob import TextBlob
consumer_key = 'aGuhSz8t2YomG33PY93OgMFvA'
consumer_secret = 'eGLPeti1aTRfV7WurSZ5a7QhJ4n4dSFSc0rgk56fjDsW63nRWc'
access_token = '826820178058977281-QEqeGT5HHaPJXgvq3MJCz6NnJuaWuZB'
access_token_secret = 'xnsm8aFq6sIhEfX6asr5qFJU1i6jne6SoywLHgsMpS37k'
auth = tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_token_secret)
api = tweepy.API(auth)
public_tweets = api.search('hacking')
for i in public_tweets:
    print(tweet.text)
    analysis = TextBlob(tweet.text)
    print(analysis.sentiment)
    print("")
# Out:
# RT @M4G4G1RL: Dear Government,
#
# After years of “War on Drugs” you can’t keep off the streets, out of our schools &amp; you can’t even keep them…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @M4G4G1RL: Dear Government,
#
# After years of “War on Drugs” you can’t keep off the streets, out of our schools &amp; you can’t even keep them…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @M4G4G1RL: Dear Government,
#
# After years of “War on Drugs” you can’t keep off the streets, out of our schools &amp; you can’t even keep them…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @M4G4G1RL: Dear Government,
#
# After years of “War on Drugs” you can’t keep off the streets, out of our schools &amp; you can’t even keep them…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @M4G4G1RL: Dear Government,
#
# After years of “War on Drugs” you can’t keep off the streets, out of our schools &amp; you can’t even keep them…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# ...

# %%
import tweepy
from textblob import TextBlob

# Step 1 - Authenticate
consumer_key = 'aGuhSz8t2YomG33PY93OgMFvA'
consumer_secret = 'eGLPeti1aTRfV7WurSZ5a7QhJ4n4dSFSc0rgk56fjDsW63nRWc'
access_token = '826820178058977281-QEqeGT5HHaPJXgvq3MJCz6NnJuaWuZB'
access_token_secret = 'xnsm8aFq6sIhEfX6asr5qFJU1i6jne6SoywLHgsMpS37k'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

#Step 3 - Retrieve Tweets
public_tweets = api.search('Want Drugs')



#CHALLENGE - Instead of printing out each tweet, save each Tweet to a CSV file
#and label each one as either 'positive' or 'negative', depending on the sentiment 
#You can decide the sentiment polarity threshold yourself


for tweet in public_tweets:
    print(tweet.text)
    
    #Step 4 Perform Sentiment Analysis on Tweets
    analysis = TextBlob(tweet.text)
    print(analysis.sentiment)
    print("")
# Out:
# RT @momof2dinosaurs: Marijuana is only a gateway drug IF YOU WANT TO DO MORE DRUGS. I've never smoked a joint and thought "hey,I wonder how…
# Sentiment(polarity=0.25, subjectivity=0.75)
#
# RT @M4G4G1RL: Dear Government,
#
# After years of “War on Drugs” you can’t keep off the streets, out of our schools &amp; you can’t even keep them…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @M4G4G1RL: Dear Government,
#
# After years of “War on Drugs” you can’t keep off the streets, out of our schools &amp; you can’t even keep them…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @chris_lin88: You can hook up with all the people you want but don't be upset when the parties or the drugs are gone and there's no one…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @M4G4G1RL: Dear Government,
#
# After years of “War on Drugs” you can’t keep off the streets, out of our schools &amp; you can’t even keep them…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# ...
